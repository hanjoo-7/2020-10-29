# %%
import FinanceDataReader as fdr
import pandas as pd
import matplotlib.pyplot as plt
import platform
from datetime import datetime, timedelta

# %%
data = pd.read_csv('C:/Users/User/Desktop/공시기반회사정보.csv', error_bad_lines=False)
# Out:
# b'Skipping line 13: expected 8 fields, saw 9\nSkipping line 22: expected 8 fields, saw 9\nSkipping line 35: expected 8 fields, saw 9\nSkipping line 39: expected 8 fields, saw 9\nSkipping line 44: expected 8 fields, saw 9\nSkipping line 74: expected 8 fields, saw 9\nSkipping line 111: expected 8 fields, saw 10\nSkipping line 114: expected 8 fields, saw 10\nSkipping line 125: expected 8 fields, saw 9\nSkipping line 130: expected 8 fields, saw 9\nSkipping line 149: expected 8 fields, saw 9\nSkipping line 157: expected 8 fields, saw 9\nSkipping line 188: expected 8 fields, saw 9\nSkipping line 200: expected 8 fields, saw 11\nSkipping line 212: expected 8 fields, saw 9\nSkipping line 244: expected 8 fields, saw 9\nSkipping line 266: expected 8 fields, saw 10\nSkipping line 286: expected 8 fields, saw 10\nSkipping line 300: expected 8 fields, saw 9\nSkipping line 306: expected 8 fields, saw 9\nSkipping line 319: expected 8 fields, saw 9\nSkipping line 333: expected 8 fields, saw 11\nSkipping line 341: expected 8 fields, saw 9\nSkipping line 347: expected 8 fields, saw 9\nSkipping line 369: expected 8 fields, saw 9\nSkipping line 373: expected 8 fields, saw 9\nSkipping line 375: expected 8 fields, saw 11\nSkipping line 376: expected 8 fields, saw 9\nSkipping line 390: expected 8 fields, saw 9\nSkipping line 432: expected 8 fields, saw 9\nSkipping line 441: expected 8 fields, saw 9\nSkipping line 446: expected 8 fields, saw 9\nSkipping line 458: expected 8 fields, saw 9\nSkipping line 489: expected 8 fields, saw 11\nSkipping line 493: expected 8 fields, saw 9\nSkipping line 535: expected 8 fields, saw 9\nSkipping line 546: expected 8 fields, saw 9\nSkipping line 551: expected 8 fields, saw 9\nSkipping line 569: expected 8 fields, saw 9\nSkipping line 586: expected 8 fields, saw 9\nSkipping line 590: expected 8 fields, saw 11\nSkipping line 605: expected 8 fields, saw 9\nSkipping line 625: expected 8 fields, saw 9\nSkipping line 642: expected 8 fields, saw 9\nSkipping line 644: expected 8 fields, saw 9\nSkipping line 650: expected 8 fields, saw 9\nSkipping line 664: expected 8 fields, saw 9\nSkipping line 674: expected 8 fields, saw 10\nSkipping line 676: expected 8 fields, saw 9\nSkipping line 678: expected 8 fields, saw 9\nSkipping line 683: expected 8 fields, saw 9\nSkipping line 684: expected 8 fields, saw 9\nSkipping line 704: expected 8 fields, saw 9\nSkipping line 728: expected 8 fields, saw 9\nSkipping line 757: expected 8 fields, saw 9\nSkipping line 768: expected 8 fields, saw 9\nSkipping line 799: expected 8 fields, saw 10\nSkipping line 801: expected 8 fields, saw 9\nSkipping line 832: expected 8 fields, saw 9\nSkipping line 846: expected 8 fields, saw 9\nSkipping line 861: expected 8 fields, saw 9\nSkipping line 863: expected 8 fields, saw 9\nSkipping line 876: expected 8 fields, saw 9\nSkipping line 885: expected 8 fields, saw 9\nSkipping line 894: expected 8 fields, saw 11\nSkipping line 903: expected 8 fields, saw 9\nSkipping line 911: expected 8 fields, saw 9\nSkipping line 923: expected 8 fields, saw 9\nSkipping line 925: expected 8 fields, saw 10\nSkipping line 932: expected 8 fields, saw 9\nSkipping line 939: expected 8 fields, saw 10\nSkipping line 943: expected 8 fields, saw 9\nSkipping line 953: expected 8 fields, saw 9\nSkipping line 956: expected 8 fields, saw 9\nSkipping line 983: expected 8 fields, saw 11\nSkipping line 1021: expected 8 fields, saw 9\nSkipping line 1028: expected 8 fields, saw 9\nSkipping line 1036: expected 8 fields, saw 9\nSkipping line 1050: expected 8 fields, saw 9\nSkipping line 1052: expected 8 fields, saw 11\nSkipping line 1075: expected 8 fields, saw 9\nSkipping line 1083: expected 8 fields, saw 10\nSkipping line 1090: expected 8 fields, saw 9\nSkipping line 1094: expected 8 fields, saw 9\nSkipping line 1130: expected 8 fields, saw 10\nSkipping line 1131: expected 8 fields, saw 10\nSkipping line 1137: expected 8 fields, saw 10\nSkipping line 1147: expected 8 fields, saw 9\nSkipping li ...

# %% [markdown]
# ## 경기선행지표

# %%
platform.system()
if platform.system() == 'Windows': 
    plt.rc('font', family='Malgun Gothic')
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (12,6)
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.formatter.limits"] = -10000, 10000

# %%
df = fdr.DataReader('NASDAQCOM', data_source='fred')
ax = df['2020':].plot()
ax = ax.axvspan('2020-09-01', '2020-10-01', color='orange', alpha=0.2)

# %% [markdown]
# #### 나스닥 지수와 주간 실업수당 청구건수

# %%
df = fdr.DataReader(['NASDAQCOM', 'ICSA'], start='2006', end = '2010', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %% [markdown]
# #### 소비자 심리지수

# %%
df = fdr.DataReader(['NASDAQCOM', 'UMCSENT'], start='2006', end='2010', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %% [markdown]
# #### 주택판매지수

# %%
df = fdr.DataReader(['NASDAQCOM', 'HSN1F'], start='2005', end='2011', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %% [markdown]
# #### 실업률

# %%
df = fdr.DataReader(['NASDAQCOM', 'UNRATE'], start='2005', end='2011', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %% [markdown]
# #### M2통화량

# %%
df = fdr.DataReader(['NASDAQCOM', 'M2'], start='2005', end='2011', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %% [markdown]
# #### 하이일드 채권 스프레드

# %%
df = fdr.DataReader(['NASDAQCOM', 'BAMLH0A0HYM2'], start='2005', end='2011', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2007-12-01', '2009-03-30', color='gray', alpha=0.2)

# %% [markdown]
# #### 환율정보

# %%
df = fdr.DataReader('DEXKOUS', start='2019', data_source='fred')
ax = df['2020':].plot()
ax = ax.axvspan('2020-09-01', '2020-10-01', color='orange', alpha=0.2)

# %%
stocks = fdr.StockListing('KOSDAQ')
stocks
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S             특수 목적용 기계 제조업
# 3     054620  KOSDAQ  APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ   AP시스템             특수 목적용 기계 제조업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 13    035760  KOSDAQ  CJ ENM                  텔레비전 방송업
# ...      ...     ...     ...                       ...
# 2579  024060  KOSDAQ    흥구석유                 기타 전문 도매업
# 2580  010240  KOSDAQ      흥국             특수 목적용 기계 제조업
# 2581  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 2586  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2587  238490  KOSDAQ      힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# 5                           위성통신 단말기  2016-03-04         12월
# 13            의류, 생활주방, 가전제품, 보석, 기타  1999-11-23         12월
# ...                              ...         ...         ...
# 2579                            휘발유등  1994-12-07         12월
# 2580               굴삭기 Roller 및 형단조품  2009-05-12         12월
# 2581       과일음료(에이드베이스, 스무디, 착즙쥬스 등)  2015-08-07         12월
# 2586                       설계 및 감리용역  2000-02-03         12월
# 2587  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                      HomePage Region
# 0            박종익, 김세완 (각자 대표이사)          http://www.3sref.com  서울특별시
# 3                           정기로  http://www.apsholdings.co.kr    경기도
# 4                           김영주    http://www.apsystems.co.kr    경기도
# 5                           류장수         http://www.apsi.co.kr  서울특별시
# 13       Minheoi Heo, Minho Hou         http://www.cjmall.com  서울특별시
# ...                         ...                           ...    ...
# 2579                        김상우                           NaN  대구광역시
# 2580                        류명준     http://www.heungkuk.co.kr   충청남도
# 2581                   박철범, 오길영       http://www.hyungkuk.com  서울특별시
# 2586  정영균, 이목운, 허철호, 염두성 (각자대표)         http://www.heerim.com  서울특별시
# 2587                        김주환         http://www.hims.co.kr  인천광역시
#
# [1447 rows x 10 columns]

# %% [markdown]
# # 수정주가

# %%
df = fdr.DataReader('100090', '2018-04-25', '2018-05-31')
df.head(10)
# Out:
#             Open  High   Low  Close   Volume    Change
# Date
# 2018-04-25  5260  5581  5260   5490   193516  0.027513
# 2018-04-26  5645  5645  5370   5398   158006 -0.016758
# 2018-04-27  5517  5562  5379   5435    77659  0.006854
# 2018-04-30  5471  6056  5471   6020  1004284  0.107636
# 2018-05-02  6386  7529  6303   7146  2658916  0.187043
# 2018-05-03  7282  7282  6752   6871  1035089 -0.038483
# 2018-05-04  6852  8033  6770   7905  2294362  0.150488
# 2018-05-08  7749  8188  7566   7685   740863 -0.027830
# 2018-05-09  7712  7950  6953   7502   539614 -0.023813
# 2018-05-10  7639  8051  7246   7960   729428  0.061050

# %%
ax = df['Close'].plot(figsize=(15,5))

ax.axvline('2018-05-04', ls='--', color='r')

# %%
df = fdr.DataReader('005930', '2018-01-01', '2018-12-31')
ax = df['Close'].plot(figsize=(15,5))

ax.axvline('2018-05-04', ls='--', color='r')

# %% [markdown]
# # 여러 종목을 한번에

# %%
stock_list = [
  ["삼성전자", "005930"],
  ["SK하이닉스", "000660"],
  ["현대차", "005380"],
  ["셀트리온", "068270"],
  ["LG화학", "051910"],
  ["POSCO", "005490"],
  ["삼성물산", "028260"],
  ["NAVER", "035420"],
]

# %%
df_list = [fdr.DataReader(code, '2019-01-01', '2019-12-31')['Close'] for name, code in stock_list]
len(df_list)
# Out:
# 8

# %%
df = pd.concat(df_list, axis=1)
df.columns = [name for name, code in stock_list] 
df.head(10)
# Out:
#              삼성전자  SK하이닉스     현대차    셀트리온    LG화학   POSCO    삼성물산   NAVER
# Date
# 2019-01-02  38750   60600  114000  204879  337000  237000  104000  118000
# 2019-01-03  37600   57700  116500  201058  328000  237000  104500  122000
# 2019-01-04  37450   58300  119500  210132  330500  239000  107000  125500
# 2019-01-07  38750   58700  120500  206311  343000  246000  108000  131500
# 2019-01-08  38100   59200  119500  203923  349500  245500  107000  130000
# 2019-01-09  39600   63600  123000  204401  352000  255500  109000  133000
# 2019-01-10  39800   65300  123000  206789  347000  258500  108500  131000
# 2019-01-11  40500   65100  123000  206789  349000  255500  109000  131000
# 2019-01-14  40050   62100  121500  201536  350500  250000  109500  127000
# 2019-01-15  41100   64000  127500  198193  356000  256500  110500  132500

# %%
df.plot()

# %%
df[['LG화학', '삼성전자']].plot()

# %%
df[['LG화학', '삼성전자']].plot(secondary_y=['LG화학'])

# %%
df.iloc[0]
# Out:
# 삼성전자       38750
# SK하이닉스     60600
# 현대차       114000
# 셀트리온      204879
# LG화학      337000
# POSCO     237000
# 삼성물산      104000
# NAVER     118000
# Name: 2019-01-02 00:00:00, dtype: int64

# %%
df_norm = df / df.iloc[0] - 1
df_norm.plot()

# %%
df_norm.iloc[-1].sort_values(ascending=False)
# Out:
# NAVER     0.580508
# SK하이닉스    0.552805
# 삼성전자      0.440000
# 현대차       0.057018
# 삼성물산      0.043269
# POSCO    -0.002110
# LG화학     -0.057864
# 셀트리온     -0.116552
# Name: 2019-12-30 00:00:00, dtype: float64

# %% [markdown]
# ## VIX지수와 관련종목

# %%
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14, 8)
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.formatter.limits"] = -10000, 10000

# %%
vix = fdr.DataReader('VIX', '1990-01-01', '2020-03-09') # S&P 500 VIX
vix.iloc[-5:]
# Out:
#             Close   Open   High    Low  Volume  Change
# Date
# 2020-03-03  36.82  33.64  41.06  24.93     0.0  0.1017
# 2020-03-04  31.99  34.44  35.58  30.30     0.0 -0.1312
# 2020-03-05  39.62  33.61  42.84  33.54     0.0  0.2385
# 2020-03-06  41.94  41.46  54.39  40.84     0.0  0.0586
# 2020-03-09  54.46  41.94  62.12  41.94     0.0  0.2985

# %%
#vix index
ax = vix['Close'].plot(lw=2, alpha=0.8, title='COBE VIX')

# 외환위기
ax.axvspan('1997-01','1997-12', alpha=0.3, color='red') 
ax.annotate('IMF crisis', xy=('1997-12-03', 70), fontsize=20)

# 금융위기
ax.axvspan('2007-01','2008-12', alpha=0.3, color='red') 
ax.annotate('Financial crisis', xy=('2008', 70), fontsize=20) 

# 팬데믹
ax.axvspan('2019-12','2020-04', alpha=0.3, color='red') 
ax.annotate('Pandemic', xy=('2019-12', 70), fontsize=20) 

# 2020-03-09 VIX 4.46
ax.axhline(54.46, ls=':', c='g') # 51.55 (2020-03-09 VIX)
ax.annotate('54.46', xy=('2020-03-09', 54.46), fontsize=20)
# Out:
# Text(2020-03-09, 54.46, '54.46')

# %%
values = vix['2020-01-01':'2020-03-09']['Close']

ax = values.plot(figsize=(14,8), grid=True, title='COBE VIX')
ax.fill_between(values.index, 0, values, alpha=0.5)
ax.margins(0)

# %%
vix = fdr.DataReader('VIX', '2010-01-01', '2020-03-09') 
kospi = fdr.DataReader('KS11', '2010-01-01', '2020-03-09') 
sp500 = fdr.DataReader('US500', '2010-01-01', '2020-03-09')

# %%
df = pd.concat([vix['Close'], kospi['Close'], sp500['Close']], axis=1)
df.columns = ['VIX', 'KOSPI', 'S&P500']
df
# Out:
#               VIX    KOSPI   S&P500
# Date
# 2010-01-04  20.04  1696.14  1132.99
# 2010-01-05  19.35  1690.62  1136.52
# 2010-01-06  19.16  1705.32  1137.14
# 2010-01-07  19.06  1683.45  1141.69
# 2010-01-08  18.13  1695.26  1144.98
# ...           ...      ...      ...
# 2020-03-03  36.82  2014.15  3003.37
# 2020-03-04  31.99  2059.33  3130.12
# 2020-03-05  39.62  2085.26  3023.94
# 2020-03-06  41.94  2040.22  2972.37
# 2020-03-09  54.46  1954.77  2746.56
#
# [2639 rows x 3 columns]

# %% [markdown]
# #### S&P500 과 VIX 비교

# %%
df[['S&P500', 'VIX']].plot(secondary_y='VIX')

# %%
df.corr()
# Out:
#              VIX     KOSPI    S&P500
# VIX     1.000000 -0.514774 -0.439172
# KOSPI  -0.514774  1.000000  0.704733
# S&P500 -0.439172  0.704733  1.000000

# %% [markdown]
# #### 삼성 S&P500 VIX S/T 선물 ETN(H) B

# %%
fdr.DataReader('530065', '2020-01-01', '2020-03-09')['Close'].plot()

# %%
price = fdr.DataReader('530065', '2020-01-01', '2020-03-09')['Close']
#수익률
returns = price / price[0] - 1.0
returns.plot()

# %% [markdown]
# # 섹터종목의 수익률과 개별종목의 수입률 구하기

# %%
#한국거래소 KRX
krx = fdr.StockListing('KRX')
krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 2583  000547   KOSPI  흥국화재2우B                       NaN
# 2584  000545   KOSPI    흥국화재우                       NaN
# 2585  003280   KOSPI     흥아해운                    해상 운송업
# 2586  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2587  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 2583                             NaN         NaT         NaN
# 2584                             NaN         NaT         NaN
# 2585                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 2586                       설계 및 감리용역  2000-02-03         12월
# 2587  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                       HomePage Region
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                           정기로   http://www.apsholdings.co.kr    경기도
# 4                           김영주     http://www.apsystems.co.kr    경기도
# ...                         ...                            ...    ...
# 2583                        NaN                            NaN    NaN
# 2584                        NaN                            NaN    NaN
# 2585                        이환구         http://www.heung-a.com  서울특별시
# 2586  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
# 2587                        김주환          http://www.hims.co.kr  인천광역시
#
# [2588 rows x 10 columns]

# %%
krx.groupby('Sector').count().sort_values('Symbol', ascending=False)[:30]
# Out:
#                                        Symbol  Market  Name  Industry  \
# Sector
# 특수 목적용 기계 제조업                             140     140   140       140
# 소프트웨어 개발 및 공급업                            134     134   134       133
# 전자부품 제조업                                  122     122   122       121
# 자동차 신품 부품 제조업                              96      96    96        96
# 의약품 제조업                                    92      92    92        92
# 기타 금융업                                     90      90    90        88
# 기타 화학제품 제조업                                87      87    87        87
# 금융 지원 서비스업                                 75      75    75        73
# 통신 및 방송 장비 제조업                             72      72    72        72
# 반도체 제조업                                    57      57    57        57
# 1차 철강 제조업                                  57      57    57        57
# 자연과학 및 공학 연구개발업                            52      52    52        52
# 의료용 기기 제조업                                 47      47    47        46
# 일반 목적용 기계 제조업                              44      44    44        44
# 플라스틱제품 제조업                                 43      43    43        43
# 기초 화학물질 제조업                                42      42    42        42
# 기타 전문 도매업                                  41      41    41        41
# 기초 의약물질 및 생물학적 제제 제조업                      38      38    38        38
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                    35      35    35        35
# 영화, 비디오물, 방송프로그램 제작 및 배급업                  33      33    33        33
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업          33      33    33        33
# 기타 식품 제조업                                  33      33    33        33
# 봉제의복 제조업                                   28      28    28        27
# 의료용품 및 기타 의약 관련제품 제조업                      27      27    27        27
# 기계장비 및 관련 물품 도매업                           24      24    24        24
# 건물 건설업                                     23      23    23        23
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외      23      23    23        23
# 기타 금속 가공제품 제조업                             23      23    23        23
# 구조용 금속제품, 탱크 및 증기발생기 제조업                   20      20    20        20
# 1차 비철금속 제조업                                19      19    19        18
#
#                                        ListingDate  SettleMonth  \
# Sector
# 특수 목적용 기계 제조업                                  140          140
# 소프트웨어 개발 및 공급업                                 134          134
# 전자부품 제조업                                       122          122
# 자동차 신품 부품 제조업                                   96           96
# 의약품 제조업                                         92           92
# 기타 금융업                                          90           90
# 기타 화학제품 제조업                                     87           87
# 금융 지원 서비스업                                      75           75
# 통신 및 방송 장비 제조업                                  72           72
# 반도체 제조업                                         57           57
# 1차 철강 제조업                                       57           57
# 자연과학 및 공학 연구개발업                                 52           52
# 의료용 기기 제조업                                      47           47
# 일반 목적용 기계 제조업                                   44           44
# 플라스틱제품 제조업                                      43           43
# 기초 화학물질 제조업                                     42           42
# 기타 전문 도매업                                       41           41
# 기초 의약물질 및 생물학적 제제 제조업                           38           38
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                         35           35
# 영화, 비디오물, 방송프로그램 제작 및 배급업                       33           33
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업               33           33
# 기타 식품 제조업                                       33           33
# 봉제의복 제조업                                        28           28
# 의료용품 및 기타 의약 관련제품 제조업                           27           27
# 기계장비 및 관련 물품 도매업                                24           24
# 건물 건설업                                          23           23
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외           23           23
# 기타 금속 가공제품 제조업                                  23           23
# 구조용 금속제품, 탱크 및 증기발생기 제조업                        20           20
# 1차 비철금속 제조업                                     19           19
#
#                                        Representative  HomePage  Region
# Sector
# 특수 목적용 기계 제조업                                     140       130     140
# 소프트웨어 개발 및 공급업                                    134       126     134
# 전자부품 제조업                                          122       114     122
# 자동차 신품 부품 제조업                                      96        93      96
# 의약품 제조업                                            92        90      92
# 기타 금융업                                             90        79      90
# 기타 화학제품 제조업                                        87        81      87
# 금융 지원 서비스업                                         75        24      75
# 통신 및 방송 장비 제조업                                     72        65      72
# 반도체 제조업                                            57        53      57
# 1차 철강 제조업                                          57        56      57
# 자연과학 및 공학 연구개발업                                    52        48      52
# 의료용 기기 제조업                                         47        46      47
# 일반 목적용 기계 제조업                                      44        43      44
# 플라스틱제품 제조업                                         43        39      43
# 기초 화학물질 제조업                                        42        41      42
# 기타 전문 도매업                                          41        39      41
# 기초 의약물질 및 생물학적 제제 제조업                              38        36      38
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                            35        31      35
# 영화, 비디오물, 방송프로그램 제작 및 배급업                          33        33      33
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업                  33        33      33
# 기타 식품 제조업                                          33        33      33
# 봉제의복 제조업                                           28        27      28
# 의료용품 및 기타 의약 관련제품 제조업                              27        25      27
# 기계장비 및 관련 물품 도매업                                   24        23      24
# 건물 건설업                                             23        23      23
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외              23        21      23
# 기타 금속 가공제품 제조업                                     23        23      23
# 구조용 금속제품, 탱크 및 증기발생기 제조업                           20        17      20
# 1차 비철금속 제조업                                        19        18      19

# %%
sectors = dict(list(krx.groupby('Sector')))
med_sec = sectors['의료용품 및 기타 의약 관련제품 제조업']
med_sec.head(10)
# Out:
#       Symbol  Market     Name                 Sector  \
# 353   138610  KOSDAQ      나이벡  의료용품 및 기타 의약 관련제품 제조업
# 409   142280  KOSDAQ   녹십자엠에스  의료용품 및 기타 의약 관련제품 제조업
# 438   343090   KONEX    단디바이오  의료용품 및 기타 의약 관련제품 제조업
# 766   233250   KONEX  메디안디노스틱  의료용품 및 기타 의약 관련제품 제조업
# 782   059210  KOSDAQ  메타바이오메드  의료용품 및 기타 의약 관련제품 제조업
# 841   206640  KOSDAQ    바디텍메드  의료용품 및 기타 의약 관련제품 제조업
# 847   064550  KOSDAQ    바이오니아  의료용품 및 기타 의약 관련제품 제조업
# 1090  100700  KOSDAQ    세운메디칼  의료용품 및 기타 의약 관련제품 제조업
# 1139  253840  KOSDAQ      수젠텍  의료용품 및 기타 의약 관련제품 제조업
# 1244  096530  KOSDAQ       씨젠  의료용품 및 기타 의약 관련제품 제조업
#
#                          Industry ListingDate SettleMonth Representative  \
# 353                치아미백제,치과용 골이식재  2011-07-13         12월            정종평
# 409              혈액백, 진단시약, 혈액투석액  2014-12-17         12월            안은억
# 438         패혈증 치료제, 면역항암제 전달기술 등  2020-04-24         12월            박영민
# 766          동물질병 체외진단키트 및 진단용 시약  2017-06-26         12월            오진식
# 782                생체분해성봉합사,근관충전재  2008-04-15         12월            오석송
# 841                        기업인수합병  2014-12-29         12월            최의열
# 847              합성유전자,시약및유전자분석장비  2005-12-29         12월            박한오
# 1090    의료용구(체액배출기,도뇨관) 제조,도매,수출입  2008-09-30         12월            이재희
# 1139                 체외진단 기기 및 시약  2019-05-28         12월            손미진
# 1244  호흡기성 병원체 검사제품, 성감염증원인균 검사제품  2010-09-10         12월            천종윤
#
#                               HomePage Region
# 353                                NaN   충청북도
# 409        http://www.greencrossms.com    경기도
# 438           http:// www.dandibio.com  서울특별시
# 766   http://www.mediandiagnostics.com    강원도
# 782         http://wwwlmeta-biomed.com   충청북도
# 841                                NaN    강원도
# 847           http://www.bioneer.co.kr  대전광역시
# 1090        http://SEWOONMEDICAL.CO.KR   충청남도
# 1139          http://www.sugentech.com  대전광역시
# 1244              http://seegene.co.kr  서울특별시

# %% [markdown]
# ## 개별종목 데이터 가져오기

# %%
med = pd.DataFrame()

for ix, row in med_sec.iterrows():
  code, name = row['Symbol'], row['Name']
  print(code, name)
  df = fdr.DataReader(code, '2019-01-01', '2019-12-31')
  med[name] = df['Close']
# Out:
# 138610 나이벡
# 142280 녹십자엠에스
# 343090 단디바이오
# 233250 메디안디노스틱
# 059210 메타바이오메드
# 206640 바디텍메드
# 064550 바이오니아
# 100700 세운메디칼
# 253840 수젠텍
# 096530 씨젠
# 246720 아스타
# 260660 알리코제약
# 174900 앱클론
# 950130 엑세스바이오
# 153710 옵티팜
# 278380 원바이오젠
# 246960 이노테라피
# 086890 이수앱지스
# 216080 제테마
# 229000 젠큐릭스
# 228760 지노믹트리
# 046210 파나진
# 303360 프로테옴텍
# 241820 피씨엘
# 304840 피플바이오
# 042520 한스바이오메드
# 205470 휴마시스

# %%
med = med.dropna(axis=1)
acc_rets = med / med.iloc[0] - 1.0
acc_rets
# Out:
#                  나이벡    녹십자엠에스   메디안디노스틱   메타바이오메드     바디텍메드     바이오니아  \
# Date
# 2019-01-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2019-01-03 -0.070742 -0.020778  0.016667 -0.013514 -0.039423 -0.045093
# 2019-01-04 -0.023296 -0.008311  0.016667  0.001689 -0.019231 -0.021220
# 2019-01-07 -0.023296 -0.008311  0.016667  0.020270 -0.014423 -0.043767
# 2019-01-08 -0.032592 -0.016623  0.018519  0.027027 -0.040385 -0.061008
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-23  0.037615 -0.479019  0.451852 -0.087838 -0.076923 -0.128647
# 2019-12-24  0.084633 -0.487128  0.451852 -0.111486 -0.091346 -0.137931
# 2019-12-26  0.122035 -0.482060  0.451852 -0.096284 -0.070192 -0.122016
# 2019-12-27  0.148750 -0.467869  0.481481 -0.070946 -0.072115 -0.112732
# 2019-12-30  0.186151 -0.467869  0.481481 -0.059122 -0.072115 -0.099469
#
#                세운메디칼       수젠텍        씨젠       아스타  ...    엑세스바이오       옵티팜  \
# Date                                                ...
# 2019-01-02  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2019-01-03  0.013228  0.007752 -0.054487 -0.020507  ... -0.052154 -0.010953
# 2019-01-04  0.006614  0.003876 -0.038462 -0.031363  ... -0.010204  0.014239
# 2019-01-07  0.000000  0.003876 -0.025641 -0.038601  ...  0.013605 -0.003286
# 2019-01-08 -0.013228  0.000000  0.000000 -0.059107  ... -0.023810 -0.005476
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-12-23 -0.144180 -0.581395  0.903846 -0.386007  ... -0.539683 -0.006572
# 2019-12-24 -0.153439 -0.596124  0.942308 -0.392039  ... -0.531746 -0.031763
# 2019-12-26 -0.146825 -0.591473  0.942308 -0.401689  ... -0.543084 -0.035049
# 2019-12-27 -0.145503 -0.577519  0.964744 -0.414958  ... -0.532880 -0.025192
# 2019-12-30 -0.146825 -0.575194  0.964744 -0.413752  ... -0.532880 -0.009858
#
#                이수앱지스      젠큐릭스     지노믹트리       파나진     프로테옴텍       피씨엘  \
# Date
# 2019-01-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2019-01-03 -0.025932 -0.011962 -0.001815 -0.021229 -0.030928 -0.017838
# 2019-01-04  0.004862  0.028708 -0.001815  0.006704 -0.028351  0.010493
# 2019-01-07  0.029173  0.143541  0.005445  0.042458 -0.025773  0.017838
# 2019-01-08  0.021070  0.143541  0.005445  0.027933 -0.048969  0.019937
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-23  0.085900 -0.270335 -0.196007 -0.505028 -0.203608 -0.169990
# 2019-12-24  0.051864 -0.239234 -0.228675 -0.511732 -0.255155 -0.174187
# 2019-12-26  0.047002 -0.224880 -0.197822 -0.481564 -0.278351 -0.172088
# 2019-12-27  0.059968 -0.236842 -0.172414 -0.475978 -0.278351 -0.159496
# 2019-12-30  0.077796 -0.210526 -0.148820 -0.475978 -0.280928 -0.154250
#
#              한스바이오메드      휴마시스
# Date
# 2019-01-02  0.000000  0.000000
# 2019-01-03 -0.046748 -0.018727
# 2019-01-04 -0.020325 -0.003745
# 2019-01-07  0.002033  0.003745
# 2019-01-08  0.008130  0.003745
# ...              ...       ...
# 2019-12-23 -0.042683  0.029963
# 2019-12-24 -0.042683  0.014981
# 2019-12-26 -0.020325  0.014981
# 2019-12-27 -0.016260  0.037453
# 2019-12-30  0.014228  0.041199
#
# [246 rows x 22 columns]

# %%
returns = acc_rets.iloc[-1]
print(returns.mean())
returns.sort_values(ascending=False)
# Out:
# -0.08079948822100685
# 씨젠         0.964744
# 메디안디노스틱    0.481481
# 나이벡        0.186151
# 알리코제약      0.165289
# 이수앱지스      0.077796
# 휴마시스       0.041199
# 한스바이오메드    0.014228
# 옵티팜       -0.009858
# 메타바이오메드   -0.059122
# 앱클론       -0.060890
# 바디텍메드     -0.072115
# 바이오니아     -0.099469
# 세운메디칼     -0.146825
# 지노믹트리     -0.148820
# 피씨엘       -0.154250
# 젠큐릭스      -0.210526
# 프로테옴텍     -0.280928
# 아스타       -0.413752
# 녹십자엠에스    -0.467869
# 파나진       -0.475978
# 엑세스바이오    -0.532880
# 수젠텍       -0.575194
# Name: 2019-12-30 00:00:00, dtype: float64

# %% [markdown]
# ## 특정기간에 대한 수익률 구하기

# %%
df = med['2019-12-01':'2019-12-30'] 
acc_rets = df / df.iloc[0] - 1.0
the_day = datetime(2019, 12, 30)
row_dict = {}

for days in [5, 10, 20, 60, 120, 240]:
  start = the_day - timedelta(days)
  end = the_day
  df = med[start:end]
  acc_rets = df / df.iloc[0] - 1.0
  row_dict[days] = acc_rets.iloc[-1] 

df_rets = pd.DataFrame(row_dict)
df_rets
# Out:
#               5         10        20        60        120       240
# 나이벡      0.057143  0.110000  0.131498  0.140802  0.707692  0.149068
# 녹십자엠에스   0.027397 -0.003795  0.023392 -0.275862  0.013514 -0.414193
# 메디안디노스틱  0.020408  0.020408  0.000000 -0.024390  0.002506  0.261830
# 메타바이오메드  0.041121  0.029575  0.067050  0.052930  0.127530 -0.068562
# 바디텍메드   -0.002068  0.013655  0.025505  0.128655  0.084270 -0.138393
# 바이오니아    0.025680  0.057632  0.046225 -0.089812 -0.015942 -0.317588
# 세운메디칼    0.000000  0.001553  0.036977 -0.034431 -0.066570 -0.161248
# 수젠텍      0.039848  0.000000 -0.035211 -0.094215 -0.125997 -0.619444
# 씨젠       0.011551  0.040747  0.122711  0.442353  0.377528  0.261317
# 아스타     -0.020161 -0.067179 -0.074286 -0.356291 -0.041420 -0.370466
# 알리코제약    0.105882  0.014388  0.060150 -0.037543  0.602273  0.184874
# 앱클론      0.095628  0.088195  0.049738  0.116992  0.029525 -0.343699
# 엑세스바이오   0.022333 -0.026005 -0.011990 -0.021378 -0.072072 -0.492611
# 옵티팜      0.026107 -0.010941  0.018018  0.008929 -0.030043 -0.174429
# 이수앱지스    0.029412  0.000000  0.024653 -0.027778 -0.019174 -0.149616
# 젠큐릭스     0.018519  0.050955  0.034483  0.157895  0.111111 -0.373814
# 지노믹트리    0.061086  0.093240 -0.071287  0.132850  0.522727 -0.366216
# 파나진      0.010776  0.008602 -0.022917 -0.099808 -0.192771 -0.475978
# 프로테옴텍   -0.003571 -0.041237 -0.041237 -0.097087 -0.057432 -0.066890
# 피씨엘      0.021546  0.010025  0.053595 -0.122004  0.083333 -0.085131
# 한스바이오메드  0.035270  0.052743  0.068522  0.091904  0.118834 -0.105735
# 휴마시스     0.025830 -0.007143  0.014599 -0.014184 -0.047945 -0.268421

# %%
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df_rets.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_0831c940_19dc_11eb_8115_80000b8f8ea9row0_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row0_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row0_col2 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row0_col3 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row0_col4 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row0_col5 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row1_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row1_col1 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row1_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row1_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row1_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row1_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row2_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row2_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row2_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row2_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row2_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row2_col5 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row3_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row3_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row3_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row3_col3 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row3_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row3_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row4_col0 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row4_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row4_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row4_col3 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row4_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row4_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row5_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row5_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row5_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row5_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row5_col4 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row5_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row6_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row6_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row6_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row6_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row6_col4 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row6_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row7_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row7_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row7_col2 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row7_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row7_col4 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row7_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row8_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row8_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row8_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row8_col3 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row8_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row8_col5 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row9_col0 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row9_col1 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row9_col2 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row9_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row9_col4 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row9_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row10_col0 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row10_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row10_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row10_col3 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row10_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row10_col5 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row11_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row11_col1 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row11_col2 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row11_col3 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row11_col4 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row11_col5 {
#             color:  red;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row12_col0 {
#             color:  black;
#             : ;
#         }    #T_0831c940_19dc_11eb_8115_80000b8f8ea9row12_col1 {
